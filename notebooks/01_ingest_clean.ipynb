# %% [markdown]
# # 01. 2021Q1~2025Q4 적재 및 키 표준화
#
# 한글/API 컬럼을 `quarter`, `area_code`, `industry_code` 등으로 표준화하고 키를 문자열로 저장한다. 완전 동일 행만 제거하며 키 중복은 원인을 보고하고 유지한다.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.data.ingest import ingest_all
PROJECT_ROOT

# %%
diagnostics = ingest_all(project_root=PROJECT_ROOT)
diagnostics
