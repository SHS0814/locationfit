# %% [markdown]
# # 03. 업종×상권 과거 성과 생성
#
# 점포당 매출, 성장성, 안정성, 폐업 안정성, 신뢰도를 계산한다.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %% [markdown]
# 다음 단계에서 구현한다.
