# %% [markdown]
# # 04. 성공 참조 집단과 가중 KNN
#
# 성과 상위 상권을 선정하고 구조 적합도를 계산한다.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %% [markdown]
# 다음 단계에서 구현한다.
